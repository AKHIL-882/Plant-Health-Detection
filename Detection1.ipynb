# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt        #visualisation
import seaborn as sns                  #Visualisation
# %matplotlib inline

# %%
dataset = pd.read_csv('train.csv',index_col=0)

# %%
dataset.head(10)
# Out:
#            Estimated_Insects_Count  Crop_Type  ...  Season  Crop_Damage
# ID                                             ...
# F00000001                      188          1  ...     1.0          0.0
# F00000003                      209          1  ...     2.0          1.0
# F00000004                      257          1  ...     2.0          1.0
# F00000005                      257          1  ...     2.0          1.0
# F00000006                      342          1  ...     2.0          1.0
# F00000008                      448          0  ...     2.0          1.0
# F00000009                      448          0  ...     2.0          1.0
# F00000010                      577          1  ...     1.0          2.0
# F00000012                      731          0  ...     2.0          0.0
# F00000020                     1132          1  ...     1.0          2.0
#
# [10 rows x 9 columns]

# %%
dataset.tail(10)
# Out:
#            Estimated_Insects_Count  Crop_Type  ...  Season  Crop_Damage
# ID                                             ...
# F00109003                     1898          0  ...     1.0          0.0
# F00109004                     1898          0  ...     3.0          0.0
# F00109005                     1898          0  ...     1.0          0.0
# F00109007                     1898          0  ...     2.0          0.0
# F00109008                     1898          0  ...     3.0          0.0
# F00109009                     1898          0  ...     2.0          0.0
# F00109012                     1898          0  ...     3.0          0.0
# F00109014                     1898          0  ...     2.0          0.0
# F00109015                     1898          0  ...     2.0          0.0
# F00109019                     1898          0  ...     NaN          NaN
#
# [10 rows x 9 columns]

# %%
dataset.shape
# Out:
# (62181, 9)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 62181 entries, F00000001 to F00109019
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Estimated_Insects_Count  62181 non-null  int64
#  1   Crop_Type                62181 non-null  int64
#  2   Soil_Type                62180 non-null  float64
#  3   Pesticide_Use_Category   62180 non-null  float64
#  4   Number_Doses_Week        62180 non-null  float64
#  5   Number_Weeks_Used        55893 non-null  float64
#  6   Number_Weeks_Quit        62180 non-null  float64
#  7   Season                   62180 non-null  float64
#  8   Crop_Damage              62180 non-null  float64
# dtypes: float64(7), int64(2)
# memory usage: 4.7+ MB

# %%
dataset.describe()
# Out:
#        Estimated_Insects_Count     Crop_Type  ...       Season   Crop_Damage
# count             62181.000000  62181.000000  ...  62180.00000  62180.000000
# mean               1398.411669      0.284556  ...      1.89799      0.193117
# std                 849.325110      0.451207  ...      0.70209      0.456807
# min                 150.000000      0.000000  ...      1.00000      0.000000
# 25%                 731.000000      0.000000  ...      1.00000      0.000000
# 50%                1212.000000      0.000000  ...      2.00000      0.000000
# 75%                1898.000000      1.000000  ...      2.00000      0.000000
# max                4097.000000      1.000000  ...      3.00000      2.000000
#
# [8 rows x 9 columns]

# %%
crop_damage = dataset['Crop_Damage']
soil_type = dataset['Soil_Type']
correlation  = crop_damage.corr(soil_type)
correlation
# Out:
# -0.02184449418151066

# %%
# import warnings
# warnings.filterwarnings("ignore")

# dataset_corr = dataset.drop(['Crop_Damage'],axis=1) 


# crop_damage = dataset.Crop_Damage
# for i in range(dataset.shape[1]):
#     correlation = crop_damage.corr(dataset[dataset_corr.columns[i]])
#     print(dataset_corr.columns[i],">>>>>>>>>>>>>>",correlation)

# %%
corr = dataset.corr(method = 'pearson')
corr
# Out:
#                          Estimated_Insects_Count  ...  Crop_Damage
# Estimated_Insects_Count                 1.000000  ...     0.201497
# Crop_Type                              -0.085508  ...    -0.017479
# Soil_Type                              -0.054195  ...    -0.021844
# Pesticide_Use_Category                 -0.075394  ...     0.178681
# Number_Doses_Week                      -0.103661  ...    -0.034684
# Number_Weeks_Used                       0.441466  ...     0.233379
# Number_Weeks_Quit                       0.295795  ...    -0.136143
# Season                                  0.003586  ...    -0.000354
# Crop_Damage                             0.201497  ...     1.000000
#
# [9 rows x 9 columns]

# %%
sns.pairplot(dataset)

# %%
dataset.plot(kind='scatter',
             marker = '+',
             x='Crop_Damage',
             y='Estimated_Insects_Count',
             title = 'Crop_Damage Vs Estimated_Insects_Count',
             c='red')

# %%
sns.heatmap(dataset.corr(),annot=True,cmap="plasma")

# %%
print(dataset.isnull().sum)
# Out:
# <bound method DataFrame.sum of            Estimated_Insects_Count  Crop_Type  ...  Season  Crop_Damage
# ID                                             ...
# F00000001                    False      False  ...   False        False
# F00000003                    False      False  ...   False        False
# F00000004                    False      False  ...   False        False
# F00000005                    False      False  ...   False        False
# F00000006                    False      False  ...   False        False
# ...                            ...        ...  ...     ...          ...
# F00109009                    False      False  ...   False        False
# F00109012                    False      False  ...   False        False
# F00109014                    False      False  ...   False        False
# F00109015                    False      False  ...   False        False
# F00109019                    False      False  ...    True         True
#
# [62181 rows x 9 columns]>

# %%
dataset = dataset.dropna()
dataset.count()
# Out:
# Estimated_Insects_Count    55893
# Crop_Type                  55893
# Soil_Type                  55893
# Pesticide_Use_Category     55893
# Number_Doses_Week          55893
# Number_Weeks_Used          55893
# Number_Weeks_Quit          55893
# Season                     55893
# Crop_Damage                55893
# dtype: int64

# %%
dataset.shape
# Out:
# (55893, 9)

# %%
dataset.nunique()
# Out:
# Estimated_Insects_Count    71
# Crop_Type                   2
# Soil_Type                   2
# Pesticide_Use_Category      3
# Number_Doses_Week          20
# Number_Weeks_Used          64
# Number_Weeks_Quit          51
# Season                      3
# Crop_Damage                 3
# dtype: int64

# %%
l = ['Crop_Type',
'Soil_Type',
'Season',
'Crop_Damage']

for col in l:
    print("***"*40)
    print(col)
    print(dataset[col].value_counts())
    print("***"* 40)
    print("\n")
# Out:
# ************************************************************************************************************************
# Crop_Type
# 0    40003
# 1    15890
# Name: Crop_Type, dtype: int64
# ************************************************************************************************************************
#
#
# ************************************************************************************************************************
# Soil_Type
# 0.0    30460
# 1.0    25433
# Name: Soil_Type, dtype: int64
# ************************************************************************************************************************
#
#
# ************************************************************************************************************************
# Season
# 2.0    27739
# 1.0    16941
# 3.0    11213
# Name: Season, dtype: int64
# ************************************************************************************************************************
#
#
# ************************************************************************************************************************
# Crop_Damage
# 0.0    46573
# 1.0     7856
# 2.0     1464
# Name: Crop_Damage, dtype: int64
# ************************************************************************************************************************

# %%
dataset['Season'].value_counts().plot(kind = 'bar')

# %%
dataset['Crop_Damage'].value_counts().plot(kind='bar')

# %%
dataset['Soil_Type'].value_counts().plot(kind = 'bar')

# %%
dataset['Crop_Type'].value_counts().plot(kind = 'bar')

# %%
dataset.fillna(dataset.mean())
# Out:
#            Estimated_Insects_Count  Crop_Type  ...  Season  Crop_Damage
# ID                                             ...
# F00000001                      188          1  ...     1.0          0.0
# F00000003                      209          1  ...     2.0          1.0
# F00000004                      257          1  ...     2.0          1.0
# F00000005                      257          1  ...     2.0          1.0
# F00000006                      342          1  ...     2.0          1.0
# ...                            ...        ...  ...     ...          ...
# F00109005                     1898          0  ...     1.0          0.0
# F00109009                     1898          0  ...     2.0          0.0
# F00109012                     1898          0  ...     3.0          0.0
# F00109014                     1898          0  ...     2.0          0.0
# F00109015                     1898          0  ...     2.0          0.0
#
# [55893 rows x 9 columns]

# %%
dataset.describe()
# Out:
#        Estimated_Insects_Count     Crop_Type  ...        Season   Crop_Damage
# count             55893.000000  55893.000000  ...  55893.000000  55893.000000
# mean               1400.370225      0.284293  ...      1.897518      0.192940
# std                 850.402405      0.451081  ...      0.702295      0.456184
# min                 150.000000      0.000000  ...      1.000000      0.000000
# 25%                 731.000000      0.000000  ...      1.000000      0.000000
# 50%                1212.000000      0.000000  ...      2.000000      0.000000
# 75%                1898.000000      1.000000  ...      2.000000      0.000000
# max                4097.000000      1.000000  ...      3.000000      2.000000
#
# [8 rows x 9 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 55893 entries, F00000001 to F00109015
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Estimated_Insects_Count  55893 non-null  int64
#  1   Crop_Type                55893 non-null  int64
#  2   Soil_Type                55893 non-null  float64
#  3   Pesticide_Use_Category   55893 non-null  float64
#  4   Number_Doses_Week        55893 non-null  float64
#  5   Number_Weeks_Used        55893 non-null  float64
#  6   Number_Weeks_Quit        55893 non-null  float64
#  7   Season                   55893 non-null  float64
#  8   Crop_Damage              55893 non-null  float64
# dtypes: float64(7), int64(2)
# memory usage: 6.8+ MB

# %%
dataset_new = dataset.drop(['Number_Doses_Week','Number_Weeks_Used','Number_Weeks_Quit'],axis=1)

# %%
dataset_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 55893 entries, F00000001 to F00109015
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Estimated_Insects_Count  55893 non-null  int64
#  1   Crop_Type                55893 non-null  int64
#  2   Soil_Type                55893 non-null  float64
#  3   Pesticide_Use_Category   55893 non-null  float64
#  4   Season                   55893 non-null  float64
#  5   Crop_Damage              55893 non-null  float64
# dtypes: float64(4), int64(2)
# memory usage: 5.5+ MB

# %%
x = dataset.iloc[:, [0, 1, 2, 3,4,5]].values
kmeans = KMeans(n_clusters = 3)
y_pred = kmeans.fit_predict(x)

# %%
plt.figure(figsize=(8,8))
plt.scatter(x[y_pred == 0, 0], x[y_pred == 0, 1], s = 50, c = 'yellow', label = 'Cluster_1')
plt.scatter(x[y_pred == 1, 0], x[y_pred == 1, 1], s = 50, c = 'blue', label = 'Cluster_2')
plt.scatter(x[y_pred == 2, 0], x[y_pred == 2, 1], s = 50, c = 'green', label = 'Cluster_3')

#Plotting centroids of the clusters
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:,1], s = 50, c = 'red', label = 'Centroids')

plt.legend()

# %%
dataset_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 55893 entries, F00000001 to F00109015
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Estimated_Insects_Count  55893 non-null  int64
#  1   Crop_Type                55893 non-null  int64
#  2   Soil_Type                55893 non-null  float64
#  3   Pesticide_Use_Category   55893 non-null  float64
#  4   Season                   55893 non-null  float64
#  5   Crop_Damage              55893 non-null  float64
# dtypes: float64(4), int64(2)
# memory usage: 5.5+ MB

# %%
x=dataset_new[['Estimated_Insects_Count','Crop_Type','Soil_Type','Pesticide_Use_Category','Season',]]
y=dataset_new['Crop_Damage']
y = y.astype(int)

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2, random_state = 2)

# %%
from sklearn.linear_model import LinearRegression

LR  = LinearRegression()
LR.fit(x_train,y_train)
y_pred = LR.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error

print("The MSE : ", round(mean_squared_error(y_pred,y_test),2))
# Out:
# The MSE :  0.19

# %%
from pickle import dump
file = 'model.h5'
dump(LR,open(file,'wb'))

# %%
from pickle import load
x = load(open('model.h5','rb'))

# %%
dataset_new.head()
# Out:
#            Estimated_Insects_Count  Crop_Type  ...  Season  Crop_Damage
# ID                                             ...
# F00000001                      188          1  ...     1.0          0.0
# F00000003                      209          1  ...     2.0          1.0
# F00000004                      257          1  ...     2.0          1.0
# F00000005                      257          1  ...     2.0          1.0
# F00000006                      342          1  ...     2.0          1.0
#
# [5 rows x 6 columns]

# %%
# Estimated_Insects_Count 'Crop_Type','Soil_Type','Pesticide_Use_Category','Season'

y = x.predict([[150,1,1.0,2.0,0.0]])
y=(y*10).round();
y_value = abs(y)
print(abs(y))
if(y_value == 0):
  print('Not damaged')
elif(y_value == 1):
  print('need to take care')
elif(y_value == 2):
  print('fully damaged')
else:
  print('Plant has good health')
# Out:
# [1.]
# need to take care
